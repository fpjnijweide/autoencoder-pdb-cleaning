# %%
#!/usr/bin/env python
# coding: utf-8

# # Autoencoder-based cleaning of non-categorical data in probabilistic databases
# 
# This source code was used to generate the data in the paper with the same title.
# Most variables can be altered in the cell under the "Variables for experiments" heading, but some edge cases (such as adding new layers and sparsity constraints) will require manually editing the cell where the autoencoder is defined.
# The % of noise left can be found at the bottom of the output of the last cell.

# In[1]:


get_ipython().run_line_magic('matplotlib', 'inline')
# from pylab import *
import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib
import scipy.stats
import scipy.spatial
import tensorflow as tf
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
# from PIL import Image
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import sklearn.model_selection
import tensorflow.keras as keras
import os
import neural_structured_learning as nsl
import math
import gc
import gkernel
# import gkernel
# import functools

print('Imports done')
# Out:
# Imports done

# %%
def gen_experiment(input_dict={},variable=None,vars=None):
    if variable is None:
        vars = [0]
    experiment=[]
    for x in vars:
        new_experiment_config=input_dict.copy()
        if variable is not None:
            new_experiment_config[variable]=x
        new_experiment_config['string']=str(new_experiment_config)
        experiment.append(new_experiment_config)
    return experiment

experiments = []






# JSD experiments
# experiments.append(gen_experiment({'loss_function':'JSD'}))
# experiments.append(gen_experiment({'loss_function':'JSD'},'sampling_density',[4,15,25,50,100,150,300]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'hidden_layers',[3,5,7,9,27]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'encoding_dim',[2,3,6]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'activation_types',[ ['relu'],['relu','relu','relu','relu','relu'], [keras.backend.sin,keras.backend.cos,keras.activations.linear],[keras.backend.sin,keras.backend.cos,keras.activations.linear, 'relu', 'sigmoid']]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'activity_regularizer',[keras.regularizers.l2(0.01),keras.regularizers.l2(10e-5),keras.regularizers.l1(0.01),keras.regularizers.l1(10e-5)]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'sigma',[0.01*4/4,0.01/4,0.01/math.sqrt(4),0.01*4/100,0.01/100,0.01/math.sqrt(100)]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'input_layer_type',['gaussian_noise','gaussian_dropout','sqrt_softmax']))
# experiments.append(gen_experiment({'loss_function':'JSD'},'unlabeled_data_percentage',[1-(5/100),1-(1/100),1-(0.5/100),1-(0.25/100),1-(0.125/100)]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'BN_size',[2,3,4,5]))
# # JSD experiments NB100
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100}))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'hidden_layers',[3,5,7,9,27]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'encoding_dim',[2,3,6]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'activation_types',[ ['relu'],['relu','relu','relu','relu','relu'], [keras.backend.sin,keras.backend.cos,keras.activations.linear],[keras.backend.sin,keras.backend.cos,keras.activations.linear, 'relu', 'sigmoid'] ]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'activity_regularizer',[keras.regularizers.l2(0.01),keras.regularizers.l2(10e-5),keras.regularizers.l1(0.01),keras.regularizers.l1(10e-5)]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'sigma',[0.01*4/4,0.01/4,0.01/math.sqrt(4),0.01*4/100,0.01/100,0.01/math.sqrt(100)]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'input_layer_type',['gaussian_noise','gaussian_dropout','sqrt_softmax']))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'unlabeled_data_percentage',[1-(5/100),1-(1/100),1-(0.5/100),1-(0.25/100),1-(0.125/100)]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'BN_size',[2,3,4,5]))
# JSD Gaussian kernel experiments
# experiments.append(gen_experiment({'loss_function':'JSD','input_layer_type':'gaussian_kernel'},'kernel_landmarks',[25,50,100,200,500,1000]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100,'input_layer_type':'gaussian_kernel'},'kernel_landmarks',[25,50,100,200,500,1000]))


# CCE experiments
# experiments.append(gen_experiment({}))
# experiments.append(gen_experiment({},'sampling_density',[4,15,25,50,100,150,300]))
# experiments.append(gen_experiment({},'hidden_layers',[3,5,7,9,27]))
# experiments.append(gen_experiment({},'encoding_dim',[2,3,6]))
# experiments.append(gen_experiment({},'activation_types',[ ['relu'],['relu','relu','relu','relu','relu'], [keras.backend.sin,keras.backend.cos,keras.activations.linear],[keras.backend.sin,keras.backend.cos,keras.activations.linear, 'relu', 'sigmoid']]))
# experiments.append(gen_experiment({},'activity_regularizer',[keras.regularizers.l2(0.01),keras.regularizers.l2(10e-5),keras.regularizers.l1(0.01),keras.regularizers.l1(10e-5)]))
# experiments.append(gen_experiment({},'sigma',[0.01*4/4,0.01/4,0.01/math.sqrt(4),0.01*4/100,0.01/100,0.01/math.sqrt(100)]))
# experiments.append(gen_experiment({},'input_layer_type',['gaussian_noise','gaussian_dropout','sqrt_softmax']))
# experiments.append(gen_experiment({},'unlabeled_data_percentage',[1-(5/100),1-(1/100),1-(0.5/100),1-(0.25/100),1-(0.125/100)]))
# experiments.append(gen_experiment({},'BN_size',[2,3,4,5]))
# CCE experiments NB100
# experiments.append(gen_experiment({'sampling_density':100}))
# experiments.append(gen_experiment({'sampling_density':100},'hidden_layers',[3,5,7,9,27]))
# experiments.append(gen_experiment({'sampling_density':100},'encoding_dim',[2,3,6]))
# experiments.append(gen_experiment({'sampling_density':100},'activation_types',[ ['relu'],['relu','relu','relu','relu','relu'], [keras.backend.sin,keras.backend.cos,keras.activations.linear],[keras.backend.sin,keras.backend.cos,keras.activations.linear, 'relu', 'sigmoid'] ]))
# experiments.append(gen_experiment({'sampling_density':100},'activity_regularizer',[keras.regularizers.l2(0.01),keras.regularizers.l2(10e-5),keras.regularizers.l1(0.01),keras.regularizers.l1(10e-5)]))
# experiments.append(gen_experiment({'sampling_density':100},'sigma',[0.01*4/4,0.01/4,0.01/math.sqrt(4),0.01*4/100,0.01/100,0.01/math.sqrt(100)]))
# experiments.append(gen_experiment({'sampling_density':100},'input_layer_type',['gaussian_noise','gaussian_dropout','sqrt_softmax']))
# experiments.append(gen_experiment({'sampling_density':100},'unlabeled_data_percentage',[1-(5/100),1-(1/100),1-(0.5/100),1-(0.25/100),1-(0.125/100)]))
# experiments.append(gen_experiment({'sampling_density':100},'BN_size',[2,3,4,5]))
# CCE Gaussian kernel experiments
# experiments.append(gen_experiment({'input_layer_type':'gaussian_kernel'},'kernel_landmarks',[25,50,100,200,500,1000]))
# experiments.append(gen_experiment({'sampling_density':100,'input_layer_type':'gaussian_kernel'},'kernel_landmarks',[25,50,100,200,500,1000]))

# CCEu experiments
# experiments.append(gen_experiment({'training_method':'unsupervised'},'hidden_layers',[3,5,7,9,27]))
# experiments.append(gen_experiment({'training_method':'unsupervised'},'encoding_dim',[2,3,6]))
# experiments.append(gen_experiment({'training_method':'unsupervised'},'sigma',[0.01*4/4,0.01/4,0.01/math.sqrt(4),0.01*4/100,0.01/100,0.01/math.sqrt(100)]))
# experiments.append(gen_experiment({'training_method':'unsupervised'},'input_layer_type',['gaussian_noise','gaussian_dropout','sqrt_softmax']))
# experiments.append(gen_experiment({'training_method':'unsupervised'},'BN_size',[2,3,4,5]))

# vergeten CCE
# experiments.append(gen_experiment({'sampling_density':100},'unlabeled_data_percentage',[1-(5/100),1-(1/100),1-(0.5/100),1-(0.25/100),1-(0.125/100)]))
# experiments.append(gen_experiment(sampling_density':100},'sigma',[0.01*4/4,0.01/4,0.01/math.sqrt(4),0.01*4/100,0.01/100,0.01/math.sqrt(100)]))
# experiments.append(gen_experiment({'sampling_density':100},'activation_types',[ ['relu','relu','relu','relu','relu'] ]))
# experiments.append(gen_experiment({'training_method':'unsupervised','input_layer_type':'gaussian_kernel'},'kernel_landmarks',[25,50,100,200,500,1000]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'hidden_layers',[3,5,7,9,27]))


#CNN experiments
# experiments.append(gen_experiment({'loss_function':'JSD','CNN':True},'CNN_kernel_size',[1,3,5,7,9]))
# experiments.append(gen_experiment({'loss_function':'JSD','CNN':True},'CNN_filters',[16,32,64,128]))
# experiments.append(gen_experiment({'loss_function':'JSD','CNN':True,'sampling_density':100},'CNN_kernel_size',[1,3,5,7,9]))
# experiments.append(gen_experiment({'loss_function':'JSD','CNN':True,'sampling_density':100},'CNN_filters',[16,32,64,128]))


# experiments.append(gen_experiment({'loss_function':'JSD','CNN':True,'sampling_density':100,'CNN_kernel_size':100}))
# experiments.append(gen_experiment({'loss_function':'JSD','CNN':True,'sampling_density':4,'CNN_kernel_size':4}))






# TODO vae experiments


#5x relu
# experiments.append(gen_experiment({'loss_function':'JSD'},'activation_types',[ ['relu','relu','relu','relu','relu'] ]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'activation_types',[ ['relu','relu','relu','relu','relu'] ]))

# experiments.append(gen_experiment({'training_method':'unsupervised','CNN':True},'CNN_kernel_size',[1,3,5,7,9,4]))
# experiments.append(gen_experiment({'training_method':'unsupervised','CNN':True},'CNN_filters',[16,32,64,128]))
# experiments.append(gen_experiment({'CNN':True},'CNN_kernel_size',[1,3,5,7,9,4]))
# experiments.append(gen_experiment({'CNN':True},'CNN_filters',[16,32,64,128]))
# experiments.append(gen_experiment({'CNN':True,'sampling_density':100},'CNN_kernel_size',[1,3,5,7,9,100]))
# experiments.append(gen_experiment({'CNN':True,'sampling_density':100},'CNN_filters',[16,32,64,128]))



# experiments.append(gen_experiment({'training_method':'unsupervised'},'BN_size',[10,20,30]))
# experiments.append(gen_experiment({},'BN_size',[2,3,4,5,10,20,30]))
# experiments.append(gen_experiment({},'unlabeled_data_percentage',[1-(5/100),1-(1/100),1-(0.5/100),1-(0.25/100),1-(0.125/100)]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'BN_size',[10,20,30]))
# experiments.append(gen_experiment({'training_method':'unsupervised'},'sampling_density',[4,15,25,50,100,150,300]))
# experiments.append(gen_experiment({},'training_method',["supervised","supervised_2_percent","semi","semi_sup_first","semi_mixed","unsupervised"]))

# # training method
# experiments.append(gen_experiment({},'training_method',["semi_sup_first","semi_mixed","unsupervised"]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'training_method',["supervised","supervised_2_percent","semi","semi_sup_first","semi_mixed","unsupervised"]))
# experiments.append(gen_experiment({'loss_function':'MSE'},'training_method',["supervised","supervised_2_percent","semi","semi_sup_first","semi_mixed","unsupervised"]))

# experiments.append(gen_experiment({'sampling_density':100},'training_method',["supervised","supervised_2_percent","semi","semi_sup_first","semi_mixed","unsupervised"]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'training_method',["supervised","supervised_2_percent","semi","semi_sup_first","semi_mixed","unsupervised"]))
# experiments.append(gen_experiment({'loss_function':'MSE','sampling_density':100},'training_method',["supervised","supervised_2_percent","semi","semi_sup_first","semi_mixed","unsupervised"]))

# # noise
# experiments.append(gen_experiment({'training_method':'unsupervised'},'sigma',[0.05,0.1,0.2]))
# experiments.append(gen_experiment({},'sigma',[0.05,0.1,0.2]))
# experiments.append(gen_experiment({'sampling_density':100},'sigma',[0.05,0.1,0.2]))
# experiments.append(gen_experiment({'loss_function':'JSD'},'sigma',[0.05,0.1,0.2]))
# experiments.append(gen_experiment({'loss_function':'JSD','sampling_density':100},'sigma',[0.05,0.1,0.2]))


#  TODO sampling  density 150 en 300 for JSD, CCEu
# TODO training methods
# TODO VAE

# todo combination
#TODO redo JSD100?

for ex in experiments:
    for config in ex:
        print(config['string'])
# Out:
# {'training_method': 'semi_sup_first'}
# {'training_method': 'semi_mixed'}
# {'training_method': 'unsupervised'}
# {'loss_function': 'JSD', 'training_method': 'supervised'}
# {'loss_function': 'JSD', 'training_method': 'supervised_2_percent'}
# {'loss_function': 'JSD', 'training_method': 'semi'}
# {'loss_function': 'JSD', 'training_method': 'semi_sup_first'}
# {'loss_function': 'JSD', 'training_method': 'semi_mixed'}
# {'loss_function': 'JSD', 'training_method': 'unsupervised'}
# {'loss_function': 'MSE', 'training_method': 'supervised'}
# {'loss_function': 'MSE', 'training_method': 'supervised_2_percent'}
# {'loss_function': 'MSE', 'training_method': 'semi'}
# {'loss_function': 'MSE', 'training_method': 'semi_sup_first'}
# {'loss_function': 'MSE', 'training_method': 'semi_mixed'}
# {'loss_function': 'MSE', 'training_method': 'unsupervised'}
# {'sampling_density': 100, 'training_method': 'supervised'}
# {'sampling_density': 100, 'training_method': 'supervised_2_percent'}
# {'sampling_density': 100, 'training_method': 'semi'}
# {'sampling_density': 100, 'training_method': 'semi_sup_first'}
# {'sampling_density': 100, 'training_method': 'semi_mixed'}
# {'sampling_density': 100, 'training_method': 'unsupervised'}
# {'loss_function': 'JSD', 'sampling_density': 100, 'training_method': 'supervised'}
# {'loss_function': 'JSD', 'sampling_density': 100, 'training_method': 'supervised_2_percent'}
# {'loss_function': 'JSD', 'sampling_density': 100, 'training_method': 'semi'}
# {'loss_function': 'JSD', 'sampling_density': 100, 'training_method': 'semi_sup_first'}
# {'loss_function': 'JSD', 'sampling_density': 100, 'training_method': 'semi_mixed'}
# {'loss_function': 'JSD', 'sampling_density': 100, 'training_method': 'unsupervised'}
# {'loss_function': 'MSE', 'sampling_density': 100, 'training_method': 'supervised'}
# {'loss_function': 'MSE', 'sampling_density': 100, 'training_method': 'supervised_2_percent'}
# {'loss_function': 'MSE', 'sampling_density': 100, 'training_method': 'semi'}
# {'loss_function': 'MSE', 'sampling_density': 100, 'training_method': 'semi_sup_first'}
# {'loss_function': 'MSE', 'sampling_density': 100, 'training_method': 'semi_mixed'}
# {'loss_function': 'MSE', 'sampling_density': 100, 'training_method': 'unsupervised'}
# {'training_method': 'unsupervised', 'sigma': 0.05}
# {'training_method': 'unsupervised', 'sigma': 0.1}
# {'training_method': 'unsupervised', 'sigma': 0.2}
# {'sigma': 0.05}
# {'sigma': 0.1}
# {'sigma': 0.2}
# {'sampling_density': 100, 'sigma': 0.05}
# {'sampling_density': 100, 'sigma': 0.1}
# {'sampling_density': 100, 'sigma': 0.2}
# {'loss_function': 'JSD', 'sigma': 0.05}
# {'loss_function': 'JSD', 'sigma': 0.1}
# {'loss_function': 'JSD', 'sigma': 0.2}
# {'loss_function': 'JSD', 'sampling_density': 100, 'sigma': 0.05}
# {'loss_function': 'JSD', 'sampling_density': 100, 'sigma': 0.1}
# {'loss_function': 'JSD', 'sampling_density': 100, 'sigma': 0.2}

# %%
# # Default Variables for experiments.You probably want to use the cell above to change experiment vars.
BN_size_default =3 # amount of BN variables, minimum 3

mu_default, sigma_default = 0, 0.01 # Distribution of the noise
sampling_density_default =4 # How many bins the quasi-continuous variables use for distributing their probabilities. Higher_default = better approximation of continuous distributions

activation_types_default = [keras.backend.sin,keras.backend.cos,keras.activations.linear, 'relu', 'swish'] # Activation layer types
hidden_layers_default =9 # amount of hidden layers
encoding_dim_default = BN_size_default # The dimensionality of the middle layer
loss_function_default = keras.losses.categorical_crossentropy
training_method_default ='semi'
activity_regularizer_default=None
input_layer_type_default='dense'
unlabeled_data_percentage_default=0.98

epochs_default=100
VAE_default = False
CNN_default = False
kernel_landmarks_default = 100

CNN_layers_default = 1
CNN_filters_default = 64
CNN_kernel_size_default = 3

# %%
def generate_samplespace(function,x_min,x_max,measurements):
    non_normalized = [function(x) for x in np.linspace(x_min,x_max,measurements)]
    return (non_normalized / sum(non_normalized))

def normalize_df(df):
    return df.div(df.sum(axis=1), axis=0)
#     return df.subtract(df.min(axis=1), axis=0).div(df.sum(axis=1), axis=0)

def custom_loss2(y_true,y_pred,sizes_sorted):

    i=0
    total_loss = 0
    for size in sizes_sorted:
#         total_loss += keras.losses.kullback_leibler_divergence(y_true[:,i:i+size],y_pred[:,i:i+size])
        total_loss += nsl.lib.jensen_shannon_divergence(y_true[:,i:i+size],y_pred[:,i:i+size],axis=1)
        i+=size
    return total_loss

def prob_distance(x,y):
    xt=x.T # this is bad practice, but I cannot debug the statements below without doing this
    yt=y.T
    res= scipy.spatial.distance.jensenshannon(xt,yt,base=2.0)
#     print(res)
    return res

def make_bn(BN_size,sampling_density):
    bn=gum.BayesNet("Quasi-Continuous")
    a=bn.add(gum.LabelizedVariable("A","A binary variable",2))
    bn.cpt(a)[:]=[0.4, 0.6]

    if BN_size>1:
        b=bn.add(gum.RangeVariable("B","A range variable",0,sampling_density-1))
        bn.addArc(a,b)
        first = generate_samplespace(scipy.stats.norm().pdf,-10,3,sampling_density)
        second = generate_samplespace(scipy.stats.norm().pdf,-2,6,sampling_density)
        bn.cpt(b)[{'A':0}]=first
        bn.cpt(b)[{'A':1}]=second


    if BN_size>2:
        c=bn.add(gum.RangeVariable("C","Another quasi continuous variable",0,sampling_density-1))
        bn.addArc(b,c)
        l=[]
        for i in range(sampling_density):
            # the size and the parameter of gamma depends on the parent value
            k=(i*30.0)/sampling_density
            l.append(generate_samplespace(scipy.stats.gamma(k+1).pdf,4,5+k,sampling_density))
        bn.cpt(c)[:]=l


        for d in range(BN_size-3):
            # new variable
            d=bn.add(gum.RangeVariable("D"+str(d),"Another quasi continuous variable",0,sampling_density-1))
            l=[]
            bn.addArc(c,d)
            for i in range(sampling_density):
                # the size and the parameter of gamma depends on the parent value
                k=(i*30.0)/sampling_density
                l.append(generate_samplespace(scipy.stats.gamma(k+1).pdf,4,5+k,sampling_density))
            bn.cpt(d)[:]=l

    bn.cpt(a)[:]=[0.1,0.9]
    return bn

def make_df(use_previous_df,bn,mu,sigma):
    if use_previous_df:
        original_database=pd.read_csv("good_db.csv")
    else:
        gum.generateCSV(bn,"database.csv",10000)
        original_database=pd.read_csv("database.csv")
    original_database = original_database.reindex(sorted(original_database.columns), axis=1)


    size_dict = {}
    for column_name in original_database.columns:
        size_dict[column_name] = bn.variable(column_name).domainSize()

    shape = [original_database.shape[0],sum(size_dict.values())]

    df_cols_sorted = sorted(list(original_database.columns))
    sizes_sorted = [size_dict[x] for x in df_cols_sorted]
    sizes_sorted_with_leading_zero = [0] + sizes_sorted

    data=np.ones(original_database.shape[0]*original_database.shape[1])
    row = list(range(original_database.shape[0]))*original_database.shape[1]
    col = []
    for i in range(original_database.values.T.shape[0]):
        for item in original_database.values.T[i]:
            col.append(item+sum(sizes_sorted_with_leading_zero[0:i+1]))
    # print(col[20000])

    # TODO NAN ERROR HAPPENS HERE SOMEWHERE
    input3 = scipy.sparse.coo_matrix((data, (row, col)), shape=tuple(shape)).todense()

    first_id2 = df_cols_sorted[:]
    second_id2=[list(range(x)) for x in sizes_sorted]

    arrays3=[np.repeat(first_id2,sizes_sorted) , [item for sublist in second_id2 for item in sublist]]
    tuples2 = list(zip(*arrays3))
    index2 = pd.MultiIndex.from_tuples(tuples2, names=['Variable', 'Value'])

    hard_evidence = pd.DataFrame(input3,columns=index2)

    noise = np.random.normal(mu, sigma, hard_evidence.shape) # TODO different noise types?
    df = hard_evidence + noise
    df = df.clip(lower=0)
    
    for col in df_cols_sorted:
        df[col] = normalize_df(df[col])
    
    return df, hard_evidence, sizes_sorted

def vae_loss(x, x_decoded_mean, loss_function,z_log_var,z_mean):
    # adapted from https://blog.keras.io/building-autoencoders-in-keras.html
    reconstruction_loss = loss_function(x, x_decoded_mean)
    kl_loss = 1 + z_log_var - keras.backend.square(z_mean) - keras.backend.exp(z_log_var)
    kl_loss = keras.backend.sum(kl_loss, axis=-1)
    kl_loss *= -0.5
    # TODO maybe sum
    vae_loss = keras.backend.mean(reconstruction_loss + kl_loss)
    return vae_loss
#     kl_loss = - 0.5 * keras.backend.mean(1 + z_log_sigma - keras.backend.square(z_mean) - keras.backend.exp(z_log_sigma), axis=-1)
# 
#     return xent_loss + kl_loss

def sampling(args):
    # adapted from https://blog.keras.io/building-autoencoders-in-keras.html
    z_mean, z_log_var = args
    batch = keras.backend.shape(z_mean)[0]
    dim = keras.backend.int_shape(z_mean)[1]
    # by default, random_normal has mean = 0 and std = 1.0
    epsilon = keras.backend.random_normal(shape=(batch, dim))
    return z_mean + keras.backend.exp(0.5 * z_log_var) * epsilon

    

def train_network(epochs,df,hard_evidence,activation_types,hidden_layers,encoding_dim,sizes_sorted,loss_function,training_method,activity_regularizer,input_layer_type,unlabeled_data_percentage,VAE,CNN,kernel_landmarks,CNN_layers,CNN_filters,CNN_kernel_size):
    if training_method=='supervised' or training_method=="unsupervised":
        x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(df,hard_evidence, test_size=0.2) #unsupervised
    elif training_method=="supervised_2_percent":
        x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(df,hard_evidence, test_size=0.98)
    elif training_method=="semi" or training_method=="semi_supervised" or training_method=="semisupervised" or training_method=="semi_sup_first" or training_method=="semi_mixed":
        x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(df,hard_evidence, test_size=unlabeled_data_percentage) # semi supervised
        x_train_nolabel, x_test_nolabel, y_train_nolabel, y_test_nolabel = sklearn.model_selection.train_test_split(x_test,y_test,test_size=0.2) # semi supervised
    else:
        raise Exception("Invalid training method")



    x_train = np.float32(x_train)
    x_test = np.float32(x_test)
    y_train = np.float32(y_train)
    y_test = np.float32(y_test)


    # types = ['relu','relu','relu','relu','relu']
    input_dim = sum(sizes_sorted)
    # this is our input placeholder
#     input_layer = keras.layers.Input(shape=(None,input_dim))
    input_layer = keras.layers.Input(shape=(input_dim,))
    
    


    # "encoded" is the encoded representation of the input
    if input_layer_type =='dense' and not CNN:
        x = keras.layers.Dense(input_dim, activation='relu',activity_regularizer=activity_regularizer)(input_layer)
    elif CNN:
        x = tf.expand_dims(input_layer, axis=2)
        x = keras.layers.Conv1D(input_shape=(0,input_dim),filters=CNN_filters, kernel_size=CNN_kernel_size, activation='relu')(x)
        x = keras.layers.MaxPooling1D(pool_size=2)(x)
        x = keras.layers.Flatten()(x)

    elif input_layer_type == 'gaussian_noise':    
        x = keras.layers.GaussianNoise(0.01)(input_layer)
    elif input_layer_type == 'gaussian_dropout':
        x = keras.layers.GaussianDropout(0.01)(input_layer)
    elif input_layer_type == 'sqrt_softmax':
        x = keras.layers.Lambda(keras.backend.sqrt)(input_layer)
        x= keras.layers.Softmax()(x)
    elif input_layer_type == "gaussian_kernel":
        # todo look into this
        x = gkernel.GaussianKernel3(kernel_landmarks, input_dim)(input_layer)


    encode_ratio=0.1
    middle = hidden_layers//2
    hidden_layer_list = []
    for i in range(hidden_layers):
        if CNN and i < CNN_layers-1:
            # TODO reshape to 2D
            x = tf.expand_dims(x, axis=2)
            x = keras.layers.Conv1D(filters=CNN_filters, kernel_size=CNN_kernel_size, activation='relu')(x)
            x = keras.layers.MaxPooling1D(pool_size=2)(x)
            x = keras.layers.Flatten()(x)
            # TODO reshape back to 1D
        elif VAE and i==middle:
            
            # TODO sampling func
            z_mean = keras.layers.Dense(encoding_dim)(x)
            z_log_var = keras.layers.Dense(encoding_dim)(x)
            z = keras.layers.Lambda(sampling, output_shape=(encoding_dim,))([z_mean, z_log_var])
            x = z
            

        else:
            ratio = 2**(math.log2(encode_ratio)+abs(i-middle))
            size = encoding_dim if i==middle else max(( min(input_dim,int(ratio*input_dim))),encoding_dim)
    #         print(size)
            if len(activation_types)>1:
                x = keras.layers.concatenate([keras.layers.Dense(size, activation=type,activity_regularizer=activity_regularizer)(x) for type in activation_types],axis=1)
            else:
                x = keras.layers.Dense(size, activation=activation_types[0],activity_regularizer=activity_regularizer)(x)
        #     x = keras.layers.Dense(min(input_dim,int(ratio*input_dim)), activation='relu')(x)


    final_layer_list= [keras.layers.Dense(size, activation='softmax',activity_regularizer=activity_regularizer)(x) for size in sizes_sorted]

    decoded = keras.layers.concatenate(final_layer_list,axis=1)




    # this model maps an input to its reconstruction
    autoencoder = keras.models.Model(input_layer, outputs=decoded)



    hist = keras.callbacks.History()




    # In[21]:
    if VAE:
#         decoder_h = Dense(intermediate_dim, activation='relu')
#         decoder_mean = Dense(original_dim, activation='sigmoid')
#         h_decoded = decoder_h(z)
#         x_decoded_mean = decoder_mean(h_decoded)
        
#         # end-to-end autoencoder
#         vae = Model(x, x_decoded_mean)

        # encoder, from inputs to latent space
        encoder = keras.models.Model(input_layer, outputs=z_mean)
        


        # generator, from latent space to reconstructed inputs
        decoder_input = keras.layers.Input(shape=(encoding_dim,))
        x = decoder_input
        for i in range(middle+1,hidden_layers):
            # TODO refactor into function?
            ratio = 2**(math.log2(encode_ratio)+abs(i-middle))
            size = encoding_dim if i==middle else max(( min(input_dim,int(ratio*input_dim))),encoding_dim)
    #         print(size)
            if len(activation_types)>1:
                x = keras.layers.concatenate([keras.layers.Dense(size, activation=type,activity_regularizer=activity_regularizer)(x) for type in activation_types],axis=1)
            else:
                x = keras.layers.Dense(size, activation=activation_types[0],activity_regularizer=activity_regularizer)(x)

        final_layer_list_generator = [keras.layers.Dense(size, activation='softmax',activity_regularizer=activity_regularizer)(x) for size in sizes_sorted]
        decoded_generator = keras.layers.concatenate(final_layer_list_generator,axis=1)
        generator = keras.models.Model(decoder_input, outputs=decoded_generator)
        
        loss_function = lambda x, x_decoded_mean: vae_loss(x, x_decoded_mean, loss_function,z_log_var,z_mean)


        
    autoencoder.compile(optimizer='adam',loss=loss_function, metrics=['accuracy']) #semi supervised

    if training_method=='supervised' or training_method=="supervised_2_percent":
        autoencoder.fit(x_train, y_train, epochs=epochs, batch_size=32, shuffle=True, validation_data=(x_test, y_test), callbacks=[hist],verbose=1)
    elif training_method=="semi" or training_method=="semi_supervised" or training_method=="semisupervised":
        # SEMI SUPERVISED
        autoencoder.fit(x_train_nolabel, x_train_nolabel, epochs=epochs, batch_size=32, shuffle=True, validation_data=(x_test_nolabel, x_test_nolabel), callbacks=[hist],verbose=1)
        autoencoder.fit(x_train, y_train, epochs=epochs, batch_size=32, shuffle=True, validation_data=(x_test, y_test), callbacks=[hist],verbose=1)
    elif training_method=="unsupervised":
        # UNSUPERVISED
        autoencoder.fit(x_train, x_train, epochs=epochs, batch_size=32, shuffle=True, validation_data=(x_test, x_test), callbacks=[hist],verbose=1)
    elif training_method=="semi_sup_first":
        autoencoder.fit(x_train, y_train, epochs=epochs, batch_size=32, shuffle=True, validation_data=(x_test, y_test), callbacks=[hist],verbose=1)
        autoencoder.fit(x_train_nolabel, x_train_nolabel, epochs=epochs, batch_size=32, shuffle=True, validation_data=(x_test_nolabel, x_test_nolabel), callbacks=[hist],verbose=1)
    elif training_method=="semi_mixed":
        for i in range(epochs):
            autoencoder.fit(x_train_nolabel, x_train_nolabel, epochs=1, batch_size=32, shuffle=True, validation_data=(x_test_nolabel, x_test_nolabel), callbacks=[hist],verbose=1)
            autoencoder.fit(x_train, y_train, epochs=1, batch_size=32, shuffle=True, validation_data=(x_test, y_test), callbacks=[hist],verbose=1)
    else:
        raise Exception("Invalid training method")
    return autoencoder
        
def measure_performance(df, hard_evidence, autoencoder,sizes_sorted):
    test_data = df.head(10000)
    verify_data = hard_evidence.iloc[test_data.index]
    results = pd.DataFrame(autoencoder.predict(test_data))



    i=0
    distances_before=[]
    distances_after=[]
    for size in sizes_sorted:
        dist_before = prob_distance(verify_data.iloc[:,i:i+size],test_data.iloc[:,i:i+size])
        dist_after = prob_distance(verify_data.iloc[:,i:i+size],results.iloc[:,i:i+size])
        distances_before.append(np.nansum(dist_before)/len(dist_before))
        distances_after.append(np.nansum(dist_after)/len(dist_after))
        i+=size

    avg_distance_before = np.nansum([sizes_sorted[i]*distances_before[i] for i in range(len(sizes_sorted))])/sum(sizes_sorted)
    avg_distance_after = np.nansum([sizes_sorted[i]*distances_after[i] for i in range(len(sizes_sorted))])/sum(sizes_sorted)
    improvement = avg_distance_before - avg_distance_after
    noise_left = 100*avg_distance_after/avg_distance_before
    return noise_left

# %%
#-------------
def run_experiment(string="",epochs=epochs_default,use_previous_df=False,BN_size=BN_size_default,sampling_density=sampling_density_default,mu=mu_default,sigma=sigma_default,activation_types=activation_types_default,hidden_layers=hidden_layers_default,encoding_dim=encoding_dim_default,loss_function=loss_function_default,training_method=training_method_default,activity_regularizer=activity_regularizer_default,input_layer_type=input_layer_type_default,unlabeled_data_percentage=unlabeled_data_percentage_default, VAE=VAE_default,CNN=CNN_default,kernel_landmarks=kernel_landmarks_default,CNN_layers=CNN_layers_default,CNN_filters=CNN_filters_default,CNN_kernel_size=CNN_kernel_size_default):
    bn = make_bn(BN_size,sampling_density)
    df, hard_evidence, sizes_sorted = make_df(use_previous_df,bn,mu,sigma)

    if loss_function=='JSD':
        loss_function = lambda y_true,y_pred: custom_loss2(y_true,y_pred,sizes_sorted)

    autoencoder =train_network(epochs,df,hard_evidence,activation_types,hidden_layers,encoding_dim,sizes_sorted,loss_function,training_method,activity_regularizer,input_layer_type,unlabeled_data_percentage, VAE,CNN,kernel_landmarks,CNN_layers,CNN_filters,CNN_kernel_size)
    noise_left = measure_performance(df, hard_evidence, autoencoder,sizes_sorted)
    print(string+ "; " + str(100-noise_left))
    del autoencoder
    gc.collect()
    keras.backend.clear_session()

def all_experiments(experiments):
    for experiment_configs in experiments:
        print("{------- NEW EXPERIMENT ---------}; ")
        for experiment_config in experiment_configs:
#             print(experiment_config)
            run_experiment(**experiment_config)
            
all_experiments(experiments)
# Out:
# {------- NEW EXPERIMENT ---------};
# Epoch 1/100
# 245/245 [==============================] - 1s 5ms/step - loss: 3.9628 - accuracy: 0.6399 - val_loss: 3.5091 - val_accuracy: 0.6194
# Epoch 2/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4924 - accuracy: 0.6862 - val_loss: 3.4907 - val_accuracy: 0.6663
# Epoch 3/100
# 245/245 [==============================] - 1s 4ms/step - loss: 3.4840 - accuracy: 0.6987 - val_loss: 3.4830 - val_accuracy: 0.6684
# Epoch 4/100
# 245/245 [==============================] - 1s 4ms/step - loss: 3.4786 - accuracy: 0.7011 - val_loss: 3.4788 - val_accuracy: 0.6673
# Epoch 5/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4754 - accuracy: 0.7024 - val_loss: 3.4763 - val_accuracy: 0.6673
# Epoch 6/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4743 - accuracy: 0.7031 - val_loss: 3.4755 - val_accuracy: 0.6668
# Epoch 7/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4739 - accuracy: 0.7038 - val_loss: 3.4755 - val_accuracy: 0.6668
# Epoch 8/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4736 - accuracy: 0.7040 - val_loss: 3.4753 - val_accuracy: 0.6628
# Epoch 9/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4735 - accuracy: 0.7026 - val_loss: 3.4751 - val_accuracy: 0.6612
# Epoch 10/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4732 - accuracy: 0.7005 - val_loss: 3.4782 - val_accuracy: 0.6582
# Epoch 11/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4729 - accuracy: 0.7000 - val_loss: 3.4750 - val_accuracy: 0.6526
# Epoch 12/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4725 - accuracy: 0.7019 - val_loss: 3.4743 - val_accuracy: 0.6679
# Epoch 13/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4724 - accuracy: 0.6997 - val_loss: 3.4746 - val_accuracy: 0.6740
# Epoch 14/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4720 - accuracy: 0.6996 - val_loss: 3.4732 - val_accuracy: 0.6653
# Epoch 15/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4716 - accuracy: 0.6966 - val_loss: 3.4731 - val_accuracy: 0.6673
# Epoch 16/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4713 - accuracy: 0.6941 - val_loss: 3.4727 - val_accuracy: 0.6617
# Epoch 17/100
# 245/245 [==============================] - 1s 4ms/step - loss: 3.4711 - accuracy: 0.7001 - val_loss: 3.4720 - val_accuracy: 0.6648
# Epoch 18/100
# 245/245 [==============================] - 1s 4ms/step - loss: 3.4707 - accuracy: 0.6964 - val_loss: 3.4737 - val_accuracy: 0.6092
# Epoch 19/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4704 - accuracy: 0.6964 - val_loss: 3.4725 - val_accuracy: 0.6490
# Epoch 20/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4704 - accuracy: 0.6936 - val_loss: 3.4726 - val_accuracy: 0.6281
# Epoch 21/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4698 - accuracy: 0.6932 - val_loss: 3.4704 - val_accuracy: 0.6689
# Epoch 22/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4697 - accuracy: 0.6814 - val_loss: 3.4710 - val_accuracy: 0.6689
# Epoch 23/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4692 - accuracy: 0.6950 - val_loss: 3.4725 - val_accuracy: 0.6679
# Epoch 24/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4688 - accuracy: 0.6907 - val_loss: 3.4700 - val_accuracy: 0.6745
# Epoch 25/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4691 - accuracy: 0.6874 - val_loss: 3.4704 - val_accuracy: 0.6898
# Epoch 26/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4685 - accuracy: 0.6950 - val_loss: 3.4710 - val_accuracy: 0.6653
# Epoch 27/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4685 - accuracy: 0.6888 - val_loss: 3.4693 - val_accuracy: 0.6730
# Epoch 28/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4683 - accuracy: 0.6941 - val_loss: 3.4702 - val_accuracy: 0.6704
# Epoch 29/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4678 - accuracy: 0.6952 - val_loss: 3.4692 - val_accuracy: 0.6745
# Epoch 30/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4676 - accuracy: 0.6943 - val_loss: 3.4702 - val_accuracy: 0.6770
# Epoch 31/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4674 - accuracy: 0.6968 - val_loss: 3.4689 - val_accuracy: 0.6837
# Epoch 32/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4672 - accuracy: 0.6994 - val_loss: 3.4680 - val_accuracy: 0.6883
# Epoch 33/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.
100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4599 - accuracy: 0.7648 - val_loss: 3.4621 - val_accuracy: 0.7577
# Epoch 96/100
# 245/245 [==============================] - ETA: 0s - loss: 3.4601 - accuracy: 0.76 - 1s 3ms/step - loss: 3.4600 - accuracy: 0.7636 - val_loss: 3.4612 - val_accuracy: 0.7592
# Epoch 97/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4597 - accuracy: 0.7691 - val_loss: 3.4624 - val_accuracy: 0.7240
# Epoch 98/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4595 - accuracy: 0.7700 - val_loss: 3.4612 - val_accuracy: 0.7704
# Epoch 99/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4596 - accuracy: 0.7673 - val_loss: 3.4606 - val_accuracy: 0.7770
# Epoch 100/100
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4595 - accuracy: 0.7647 - val_loss: 3.4617 - val_accuracy: 0.7510
# Epoch 1/100
# 7/7 [==============================] - 1s 125ms/step - loss: 3.3156 - accuracy: 0.7750 - val_loss: 3.3082 - val_accuracy: 0.7405
# Epoch 2/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.3060 - accuracy: 0.7000 - val_loss: 3.3008 - val_accuracy: 0.7630
# Epoch 3/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.3014 - accuracy: 0.8150 - val_loss: 3.2997 - val_accuracy: 0.8432
# Epoch 4/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2983 - accuracy: 0.8950 - val_loss: 3.2986 - val_accuracy: 0.8813
# Epoch 5/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2976 - accuracy: 0.8750 - val_loss: 3.2984 - val_accuracy: 0.8558
# Epoch 6/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2968 - accuracy: 0.8200 - val_loss: 3.2987 - val_accuracy: 0.8733
# Epoch 7/100
# 7/7 [==============================] - 1s 75ms/step - loss: 3.2965 - accuracy: 0.8450 - val_loss: 3.2987 - val_accuracy: 0.8686
# Epoch 8/100
# 7/7 [==============================] - 1s 72ms/step - loss: 3.2964 - accuracy: 0.8600 - val_loss: 3.2984 - val_accuracy: 0.8649
# Epoch 9/100
# 7/7 [==============================] - 1s 74ms/step - loss: 3.2963 - accuracy: 0.8650 - val_loss: 3.2979 - val_accuracy: 0.8699
# Epoch 10/100
# 7/7 [==============================] - 1s 78ms/step - loss: 3.2962 - accuracy: 0.8700 - val_loss: 3.2976 - val_accuracy: 0.8712
# Epoch 11/100
# 7/7 [==============================] - 0s 66ms/step - loss: 3.2962 - accuracy: 0.8750 - val_loss: 3.2975 - val_accuracy: 0.8723
# Epoch 12/100
# 7/7 [==============================] - 1s 78ms/step - loss: 3.2962 - accuracy: 0.8850 - val_loss: 3.2974 - val_accuracy: 0.8736
# Epoch 13/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2961 - accuracy: 0.8850 - val_loss: 3.2974 - val_accuracy: 0.8739
# Epoch 14/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2961 - accuracy: 0.8850 - val_loss: 3.2974 - val_accuracy: 0.8748
# Epoch 15/100
# 7/7 [==============================] - 1s 72ms/step - loss: 3.2961 - accuracy: 0.8850 - val_loss: 3.2974 - val_accuracy: 0.8747
# Epoch 16/100
# 7/7 [==============================] - 0s 66ms/step - loss: 3.2961 - accuracy: 0.8900 - val_loss: 3.2973 - val_accuracy: 0.8763
# Epoch 17/100
# 7/7 [==============================] - 0s 67ms/step - loss: 3.2961 - accuracy: 0.8950 - val_loss: 3.2973 - val_accuracy: 0.8768
# Epoch 18/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2961 - accuracy: 0.8950 - val_loss: 3.2973 - val_accuracy: 0.8780
# Epoch 19/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2961 - accuracy: 0.8900 - val_loss: 3.2973 - val_accuracy: 0.8782
# Epoch 20/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2961 - accuracy: 0.8900 - val_loss: 3.2972 - val_accuracy: 0.8783
# Epoch 21/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2960 - accuracy: 0.8900 - val_loss: 3.2972 - val_accuracy: 0.8791
# Epoch 22/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2960 - accuracy: 0.8900 - val_loss: 3.2972 - val_accuracy: 0.8784
# Epoch 23/100
# 7/7 [==============================] - 1s 80ms/step - loss: 3.2960 - accuracy: 0.8950 - val_loss: 3.2972 - val_accuracy: 0.8781
# Epoch 24/100
# 7/7 [==============================] - 1s 73ms/step - loss: 3.2960 - accuracy: 0.8950 - val_loss: 3.2972 - val_accuracy: 0.8795
# Epoch 25/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2960 - accuracy: 0.8950 - val_loss: 3.2971 - val_accuracy: 0.8801
# Epoch 26/100
# 7/7 [==============================] - 1s 81ms/step - loss: 3.2960 - accuracy: 0.8950 - val_loss: 3.2971 - val_accuracy: 0.8798
# Epoch 27/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2960 - accuracy: 0.8950 - val_loss: 3.2971 - val_accuracy: 0.8810
# Epoch 28/100
# 7/7 [==============================] - 1s 72ms/step - loss: 3.2960 - accuracy: 0.9000 - val_loss: 3.2971 - val_accuracy: 0.8826
# Epoch 29/100
# 7/7 [==============================] - 1s 75ms/step - loss: 3.2960 - accuracy: 0.8950 - val_loss: 3.2971 - val_accuracy: 0.8827
# Epoch 30/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2960 - accuracy: 0.8950 - val_loss: 3.2971 - val_accuracy: 0.8824
# Epoch 31/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2960 - accuracy: 0.9000 - val_loss: 3.2971 - val_accuracy: 0.8824
# Epoch 32/100
# 7/7 [==============================] - 1s 75ms/step - loss: 3.2960 - accuracy: 0.9050 - val_loss: 3.2971 - val_accuracy: 0.8821
# Epoch 33/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2960 - accuracy: 0.9050 - val_loss: 3.2970 - val_accuracy: 0.8828
# Epoch 34/100
# 7/7 [==============================] - 1s 78ms/step - loss: 3.2960 - accuracy: 0.9100 - val_loss: 3.2970 - val_accuracy: 0.8841
# Epoch 35/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2960 - accuracy: 0.9050 - val_loss: 3.2970 - val_accuracy: 0.8841
# Epoch 36/100
# 7/7 [==============================] - 0s 67ms/step - loss: 3.2960 - accuracy: 0.9050 - val_loss: 3.2970 - val_accuracy: 0.8843
# Epoch 37/100
# 7/7 [==============================] - 1s 72ms/step - loss: 3.2960 - accuracy: 0.9050 - val_loss: 3.2970 - val_accuracy: 0.8841
# Epoch 38/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2960 - accuracy: 0.9000 - val_loss: 3.2970 - val_accuracy: 0.8837
# Epoch 39/100
# 7/7 [==============================] - 0s 66ms/step - loss: 3.2960 - accuracy: 0.9000 - val_loss: 3.2970 - val_accuracy: 0.8842
# Epoch 40/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2960 - accuracy: 0.9000 - val_loss: 3.2970 - val_accuracy: 0.8836
# Epoch 41/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2960 - accuracy: 0.9000 - val_loss: 3.2970 - val_accuracy: 0.8841
# Epoch 42/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2960 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8838
# Epoch 43/100
# 7/7 [==============================] - 1s 78ms/step - loss: 3.2960 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8844
# Epoch 44/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8846
# Epoch 45/100
# 7/7 [==============================] - 1s 75ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8840
# Epoch 46/100
# 7/7 [==============================] - 0s 67ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8837
# Epoch 47/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8840
# Epoch 48/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8839
# Epoch 49/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2969 - val_accuracy: 0.8834
# Epoch 50/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.9050 - val_loss: 3.2969 - val_accuracy: 0.8828
# Epoch 51/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8830
# Epoch 52/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2969 - val_accuracy: 0.8831
# Epoch 53/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.9050 - val_loss: 3.2969 - val_accuracy: 0.8827
# Epoch 54/100
# 7/7 [==============================] - 1s 81ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8835
# Epoch 55/100
# 7/7 [==============================] - 0s 67ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2969 - val_accuracy: 0.8839
# Epoch 56/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2969 - val_accuracy: 0.8839
# Epoch 57/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2968 - val_accuracy: 0.8836
# Epoch 58/100
# 7/7 [==============================] - 0s 64ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2968 - val_accuracy: 0.8834
# Epoch 59/100
# 7/7 [==============================] - 1s 77ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8832
# Epoch 60/100
# 7/7 [==============================] - 0s 66ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8833
# Epoch 61/100
# 7/7 [==============================] - 0s 67ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8832
# Epoch 62/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8833
# Epoch 63/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8829
# Epoch 64/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.8900 - val_loss: 3.2968 - val_accuracy: 0.8829
# Epoch 65/100
# 7/7 [==============================] - 1s 76ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8822
# Epoch 66/100
# 7/7 [==============================] - 0s 64ms/step - loss: 3.2959 - accuracy: 0.8900 - val_loss: 3.2968 - val_accuracy: 0.8819
# Epoch 67/100
# 7/7 [==============================] - 0s 66ms/step - loss: 3.2959 - accuracy: 0.8900 - val_loss: 3.2968 - val_accuracy: 0.8821
# Epoch 68/100
# 7/7 [==============================] - 1s 75ms/step - loss: 3.2959 - accuracy: 0.8900 - val_loss: 3.2968 - val_accuracy: 0.8818
# Epoch 69/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.8900 - val_loss: 3.2968 - val_accuracy: 0.8816
# Epoch 70/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8813
# Epoch 71/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8814
# Epoch 72/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8814
# Epoch 73/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.9050 - val_loss: 3.2968 - val_accuracy: 0.8812
# Epoch 74/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2968 - val_accuracy: 0.8812
# Epoch 75/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2968 - val_accuracy: 0.8808
# Epoch 76/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2968 - val_accuracy: 0.8809
# Epoch 77/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8806
# Epoch 78/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8805
# Epoch 79/100
# 7/7 [==============================] - 1s 73ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2968 - val_accuracy: 0.8806
# Epoch 80/100
# 7/7 [==============================] - 0s 64ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8806
# Epoch 81/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8805
# Epoch 82/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8805
# Epoch 83/100
# 7/7 [==============================] - 0s 67ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8806
# Epoch 84/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8808
# Epoch 85/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8810
# Epoch 86/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8811
# Epoch 87/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8802
# Epoch 88/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8803
# Epoch 89/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8803
# Epoch 90/100
# 7/7 [==============================] - 0s 71ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8807
# Epoch 91/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8802
# Epoch 92/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8805
# Epoch 93/100
# 7/7 [==============================] - 1s 73ms/step - loss: 3.2959 - accuracy: 0.8950 - val_loss: 3.2967 - val_accuracy: 0.8810
# Epoch 94/100
# 7/7 [==============================] - 0s 66ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8809
# Epoch 95/100
# 7/7 [==============================] - 0s 68ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8811
# Epoch 96/100
# 7/7 [==============================] - 0s 70ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8804
# Epoch 97/100
# 7/7 [==============================] - 0s 67ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8804
# Epoch 98/100
# 7/7 [==============================] - 0s 65ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8802
# Epoch 99/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8806
# Epoch 100/100
# 7/7 [==============================] - 0s 69ms/step - loss: 3.2959 - accuracy: 0.9000 - val_loss: 3.2967 - val_accuracy: 0.8805
# {'training_method': 'semi_sup_first'}; 96.01906980001067
# 245/245 [==============================] - 1s 5ms/step - loss: 3.9862 - accuracy: 0.6636 - val_loss: 3.5185 - val_accuracy: 0.5117
# 7/7 [==============================] - 1s 116ms/step - loss: 3.3476 - accuracy: 0.7150 - val_loss: 3.3589 - val_accuracy: 0.9163
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4995 - accuracy: 0.6842 - val_loss: 3.4909 - val_accuracy: 0.6786
# 7/7 [==============================] - 0s 65ms/step - loss: 3.3347 - accuracy: 0.9800 - val_loss: 3.3349 - val_accuracy: 0.9668
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4864 - accuracy: 0.6879 - val_loss: 3.4792 - val_accuracy: 0.6709
# 7/7 [==============================] - 0s 66ms/step - loss: 3.3232 - accuracy: 0.9400 - val_loss: 3.3213 - val_accuracy: 0.9684
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4792 - accuracy: 0.6949 - val_loss: 3.4778 - val_accuracy: 0.6883
# 7/7 [==============================] - 0s 69ms/step - loss: 3.3209 - accuracy: 0.9550 - val_loss: 3.3181 - val_accuracy: 0.9805
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4784 - accuracy: 0.6971 - val_loss: 3.4766 - val_accuracy: 0.6944
# 7/7 [==============================] - 0s 64ms/step - loss: 3.3217 - accuracy: 1.0000 - val_loss: 3.3174 - val_accuracy: 0.9976
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4762 - accuracy: 0.7088 - val_loss: 3.4758 - val_accuracy: 0.6944
# 7/7 [==============================] - 0s 63ms/step - loss: 3.3200 - accuracy: 1.0000 - val_loss: 3.3154 - val_accuracy: 0.9986
# 245/245 [==============================] - 1s 3ms/step - loss: 3.4757 - accuracy: 0.7082 - val_loss: 3.4756 - val_accuracy: 0.6985
# 7/7 [==============================] - 0s 64ms/step - loss: 3.3207 - accuracy: 1.0000 - val_loss: 3.3148 - val_accuracy: 0.9972
# 245/245 [==============================] - 1s 3ms/step - loss: 3.
ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 2/100
# 7/7 [==============================] - 2s 261ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 3/100
# 7/7 [==============================] - 2s 266ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 4/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 5/100
# 7/7 [==============================] - 2s 259ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 6/100
# 7/7 [==============================] - 2s 264ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 7/100
# 7/7 [==============================] - 2s 264ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 8/100
# 7/7 [==============================] - 2s 258ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 9/100
# 7/7 [==============================] - 2s 261ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 10/100
# 7/7 [==============================] - 2s 269ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 11/100
# 7/7 [==============================] - 2s 262ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 12/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 13/100
# 7/7 [==============================] - 2s 259ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 14/100
# 7/7 [==============================] - 2s 267ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 15/100
# 7/7 [==============================] - 2s 263ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 16/100
# 7/7 [==============================] - 2s 263ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 17/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 18/100
# 7/7 [==============================] - 2s 271ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 19/100
# 7/7 [==============================] - 2s 263ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 20/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 21/100
# 7/7 [==============================] - 2s 263ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 22/100
# 7/7 [==============================] - 2s 272ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 23/100
# 7/7 [==============================] - 2s 262ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 24/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 25/100
# 7/7 [==============================] - 2s 261ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 26/100
# 7/7 [==============================] - 2s 264ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 27/100
# 7/7 [==============================] - 2s 259ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 28/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 29/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 30/100
# 7/7 [==============================] - 2s 264ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 31/100
# 7/7 [==============================] - 2s 263ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 32/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 33/100
# 7/7 [==============================] - 2s 258ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 34/100
# 7/7 [==============================] - 2s 264ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 35/100
# 7/7 [==============================] - 2s 261ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 36/100
# 7/7 [==============================] - 2s 259ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 37/100
# 7/7 [==============================] - 2s 261ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 38/100
# 7/7 [==============================] - 2s 265ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 39/100
# 7/7 [==============================] - 2s 260ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 40/100
# 7/7 [==============================] - 2s 261ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 41/100
# 7/7 [==============================] - 2s 263ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 42/100
# 7/7 [==============================] - 2s 263ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 43/100
# 7/7 [==============================] - 2s 259ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 44/100
# 7/7 [==============================] - 2s 277ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 45/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 46/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 47/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 48/100
# 7/7 [==============================] - 2s 290ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 49/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 50/100
# 7/7 [==============================] - 2s 285ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 51/100
# 7/7 [==============================] - 2s 288ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 52/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 53/100
# 7/7 [==============================] - 2s 284ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 54/100
# 7/7 [==============================] - 2s 289ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 55/100
# 7/7 [==============================] - 2s 282ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 56/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 57/100
# 7/7 [==============================] - 2s 290ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 58/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 59/100
# 7/7 [==============================] - 2s 284ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 60/100
# 7/7 [==============================] - 2s 308ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 61/100
# 7/7 [==============================] - 2s 317ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 62/100
# 7/7 [==============================] - 2s 315ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 63/100
# 7/7 [==============================] - 2s 312ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 64/100
# 7/7 [==============================] - 2s 304ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 65/100
# 7/7 [==============================] - 2s 287ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 66/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 67/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 68/100
# 7/7 [==============================] - 2s 294ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 69/100
# 7/7 [==============================] - 2s 280ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 70/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 71/100
# 7/7 [==============================] - 2s 290ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 72/100
# 7/7 [==============================] - 2s 285ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 73/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 74/100
# 7/7 [==============================] - 2s 287ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 75/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 76/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 77/100
# 7/7 [==============================] - 2s 293ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 78/100
# 7/7 [==============================] - 2s 285ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 79/100
# 7/7 [==============================] - 2s 280ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 80/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 81/100
# 7/7 [==============================] - 2s 284ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 82/100
# 7/7 [==============================] - 2s 285ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 83/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 84/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 85/100
# 7/7 [==============================] - 2s 281ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 86/100
# 7/7 [==============================] - 2s 287ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 87/100
# 7/7 [==============================] - 2s 285ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 88/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 89/100
# 7/7 [==============================] - 2s 284ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 90/100
# 7/7 [==============================] - 2s 285ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 91/100
# 7/7 [==============================] - 2s 285ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 92/100
# 7/7 [==============================] - 2s 284ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 93/100
# 7/7 [==============================] - 2s 287ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 94/100
# 7/7 [==============================] - 2s 282ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 95/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 96/100
# 7/7 [==============================] - 2s 285ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 97/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 98/100
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 99/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# Epoch 100/100
# 7/7 [==============================] - 2s 286ms/step - loss: 1.4106 - accuracy: 0.9150 - val_loss: 1.4287 - val_accuracy: 0.8990
# {'loss_function': 'JSD', 'sampling_density': 100, 'sigma': 0.2}; -14.178074997015699
